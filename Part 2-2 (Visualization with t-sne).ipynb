# %%
from sklearn.manifold import TSNE
import matplotlib as mpl
import matplotlib.pyplot as plt
import gensim
import gensim.models as g

mpl.rcParams['axes.unicode_minus']=False
model_name = '300features_40minwords_10text'
model = g.Doc2Vec.load(model_name)

vocab = list(model.wv.vocab)
x = model[vocab]

print(len(x))
print(x[0][:10])
tsne = TSNE(n_components=2)

x_tsne = tsne.fit_transform(x[:100,:])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if sys.path[0] == '':
# 11986
# [-0.00703412 -0.01850145 -0.00923645  0.10716132 -0.04012663  0.04635368
#   0.00182218  0.05114942 -0.0027134   0.06160283]

# %%
import pandas as pd
df = pd.DataFrame(x_tsne, index = vocab[:100], columns=['x','y'])
df.shape
# Out:
# (100, 2)

# %%
df.head()
# Out:
#                 x         y
# ridden   1.374626 -0.057923
# caller   1.774558 -5.990185
# anymor  -6.659866 -0.015039
# dale     3.184695 -4.562115
# custodi  0.186567 -5.565510

# %%
fig = plt.figure()
fig.set_size_inches(40,20)
ax = fig.add_subplot(1,1,1)

ax.scatter(df['x'], df['y'])

for word, pos in df.iterrows():
    ax.annotate(word, pos, fontsize=30)
plt.show()
